# %% [markdown]
# # <span style = "color: green"> Employee attrition Classification </span>

# %% [markdown]
# ***

# %% [markdown]
# The issue of keeping one's employees happy and satisfied is a perennial and age-old challenge. If an employee you have invested so much time and money leaves for "greener pastures", then this would mean that you would have to spend even more time and money to hire somebody else. In the spirit of Kaggle, let us therefore turn to our predictive modelling capabilities and see if we can predict employee attrition on this synthetically generated IBM dataset.

# %% [markdown]
# ### Let's Dive into it

# %% [markdown]
# #### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read 'HR-Employee-Attrition.csv' dataset and store it inside a variable

# %%
df = pd.read_csv('HR-Employee-Attrition.csv')

# %% [markdown]
# ### Check head

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ### Check last 5 rows

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %% [markdown]
# ### Check shape

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### View info about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### View basic statistical information about the dataset

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Check for null values

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### View unique values in all categorical columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
columns=['Attrition','BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
for column in columns:
    print(f'Unique values in {column} are: {df[column].unique()}')
# Out:
# Unique values in Attrition are: ['Yes' 'No']
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Unique values in Department are: ['Sales' 'Research & Development' 'Human Resources']
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Unique values in Gender are: ['Female' 'Male']
# Unique values in JobRole are: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# Unique values in MaritalStatus are: ['Single' 'Married' 'Divorced']
# Unique values in Over18 are: ['Y']
# Unique values in OverTime are: ['Yes' 'No']

# %% [markdown]
# ### Check the number of unique values in all columns

# %%
for i in df.columns:
    print(f'Number of unique values in elements in {i} are : {df[i].nunique()}')
# Out:
# Number of unique values in elements in Age are : 43
# Number of unique values in elements in Attrition are : 2
# Number of unique values in elements in BusinessTravel are : 3
# Number of unique values in elements in DailyRate are : 886
# Number of unique values in elements in Department are : 3
# Number of unique values in elements in DistanceFromHome are : 29
# Number of unique values in elements in Education are : 5
# Number of unique values in elements in EducationField are : 6
# Number of unique values in elements in EmployeeCount are : 1
# Number of unique values in elements in EmployeeNumber are : 1470
# Number of unique values in elements in EnvironmentSatisfaction are : 4
# Number of unique values in elements in Gender are : 2
# Number of unique values in elements in HourlyRate are : 71
# Number of unique values in elements in JobInvolvement are : 4
# Number of unique values in elements in JobLevel are : 5
# Number of unique values in elements in JobRole are : 9
# ...

# %% [markdown]
# ### Print out the names of the columns having only one unique values

# %%
for i in df.columns:
    if df[i].nunique()==1:
        print(i)
# Out:
# EmployeeCount
# Over18
# StandardHours

# %% [markdown]
# ### Drop these columns as they won't be useful in our predicition

# %%
df.drop(columns =['EmployeeCount','Over18','StandardHours'],inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# ...

# %% [markdown]
# ### Drop EmployeeNumber column aswell

# %%
df.drop(columns='EmployeeNumber',inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %% [markdown]
# ### Create following groupby valuecounts

# %%
df.groupby(['Department', 'EducationField'])['Gender'].value_counts()
# Out:
# Department              EducationField    Gender
# Human Resources         Human Resources   Male       19
#                                           Female      8
#                         Life Sciences     Female      9
#                                           Male        7
#                         Medical           Male       11
#                                           Female      2
#                         Other             Male        3
#                         Technical Degree  Male        3
#                                           Female      1
# Research & Development  Life Sciences     Male      274
#                                           Female    166
#                         Medical           Male      211
#                                           Female    152
#                         Other             Male       39
#                                           Female     25
#                         Technical Degree  Male       58
# ...

# %% [markdown]
# # <span style = "color: orange"> Data Visualization </span>

# %% [markdown]
# ### Plot the following

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.countplot(x='Attrition',data=df)
plt.ylabel('No of employess')
# Out:
# Text(0, 0.5, 'No of employess')

# %%
sns.countplot(x='Attrition',data=df,hue='Gender')
plt.ylabel('No of employess')
# Out:
# Text(0, 0.5, 'No of employess')

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
#
#    Gender  HourlyRate  JobInvolvement  JobLevel             JobRole  \
# 0  Female          94               3         2     Sales Executive
# 1    Male          61               2         2  Research Scientist
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# ...

# %%
sns.countplot(x='BusinessTravel',data=df,hue='JobRole')
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(x='OverTime',data=df,hue='MaritalStatus')
# Out:
# <Axes: xlabel='OverTime', ylabel='count'>

# %%
sns.barplot(x='MonthlyIncome',y='JobRole',data=df)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='JobRole'>

# %%
sns.barplot(x='MonthlyIncome',y='Gender',data=df)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Gender'>

# %%
sns.barplot(x='MonthlyIncome',y='EducationField',data=df)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='EducationField'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='JobSatisfaction',data=df,hue='JobRole')
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='count'>

# %%
sns.displot(x=df['Age'])
# Out:
# C:\Users\shrid\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Convert Attrition from ('Yes', 'No') to (1,0)

# %%
df['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
df['Attrition'] = df['Attrition'].apply(lambda x:1 if x=='Yes' else 0)

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %% [markdown]
# ### Convert the rest of the categorical values into numeric using dummy variables and store the results in a new dataframe called 'newdf'

# %%
new_df = pd.get_dummies(df,drop_first=True)

# %%
new_df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0                4           5993        19479                   8
# 1                2           5130        24907                   1
# ...

# %% [markdown]
# #### Check the shape of our new dataset

# %%
new_df.shape
# Out:
# (1470, 45)

# %% [markdown]
# #### Print unique values in our new dataframe

# %%
for i in new_df.columns:
    print(f'Unique values in {i} are : {df[i].unique()}')
# Out:
# Unique values in Age are : [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# Unique values in Attrition are : [1 0]
# Unique values in DailyRate are : [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
# ...

# %% [markdown]
# #### Split the columns into input and target variables (X and y)

# %%
new_df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0                4           5993        19479                   8
# 1                2           5130        24907                   1
# ...

# %%
x = new_df.drop(columns='Attrition')
y = new_df['Attrition']

# %% [markdown]
# #### Carry out Feature scaling using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = pd.DataFrame(scaler.fit_transform(x),columns = x.columns)

# %%
x.head()
# Out:
#         Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0  0.446350   0.742527         -1.010909  -0.891688                -0.660531
# 1  1.322365  -1.297775         -0.147150  -1.868426                 0.254625
# 2  0.008343   1.414363         -0.887515  -0.891688                 1.169781
# 3 -0.429664   1.461466         -0.764121   1.061787                 1.169781
# 4 -1.086676  -0.524295         -0.887515  -1.868426                -1.575686
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0    1.383138        0.379672 -0.057788         1.153254      -0.108350
# 1   -0.240677       -1.026167 -0.057788        -0.660853      -0.291719
# 2    1.284725       -1.026167 -0.961486         0.246200      -0.937654
# 3   -0.486709        0.379672 -0.961486         0.246200      -0.763634
# 4   -1.274014        0.379672 -0.961486        -0.660853      -0.644858
#
# ...

# %% [markdown]
# ### Split the dataset into training and testing set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## Machine Learning Models

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.9013605442176871

# %%
y_pred = model.predict(x_test)

# %%
print(f'Accuracy score of our model is : {metrics.accuracy_score(y_test,y_pred)}')
print(f'Confusion matrix is : {metrics.confusion_matrix(y_test,y_pred)}')
print(f'Accuracy score is :{metrics.classification_report(y_test,y_pred)} ')
cvs3 = cross_val_score(LogisticRegression(),x,y,cv=5)
print(f'Cross val score:{cvs3.mean()}')
# Out:
# Accuracy score of our model is : 0.8571428571428571
# Confusion matrix is : [[230  11]
#  [ 31  22]]
# Accuracy score is :              precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92       241
#            1       0.67      0.42      0.51        53
#
#     accuracy                           0.86       294
#    macro avg       0.77      0.68      0.71       294
# weighted avg       0.84      0.86      0.84       294
#
# Cross val score:0.8829931972789116

# %% [markdown]
# <span style = "color:orange"> Visualize confusion matrix </span>

# %%
sns.heatmap(metrics.confusion_matrix(y_test,y_pred),annot=True,fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### Random Forest Classifier
# ** Choose the best estimator and parameters :GridSearchCV**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
paras = {'max_depth':[None,1,5,10],'n_estimators':[16,32,50,100],'n_jobs':[1,2],'random_state':[1,10,20,42]}

# %%
gsv = GridSearchCV(RandomForestClassifier(),paras,cv=5,scoring='accuracy')

# %%
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 1, 5, 10],
#                          'n_estimators': [16, 32, 50, 100], 'n_jobs': [1, 2],
#                          'random_state': [1, 10, 20, 42]},
#              scoring='accuracy')

# %%
print(f'Best estimator are:{gsv.best_estimator_}')
print(f'Best parameters are:{gsv.best_params_}')
print(f'Best score is: {gsv.best_score_}')
# Out:
# Best estimator are:RandomForestClassifier(max_depth=10, n_estimators=32, n_jobs=1, random_state=1)
# Best parameters are:{'max_depth': 10, 'n_estimators': 32, 'n_jobs': 1, 'random_state': 1}
# Best score is: 0.8639379733141002

# %% [markdown]
# <span style = "color:blue"> Create Random forest model with the best parameters </span>

# %%
best_rf_model = RandomForestClassifier(max_depth=10,n_jobs=1,n_estimators=32,random_state=1)

# %%
best_rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=32, n_jobs=1, random_state=1)

# %%
rf_y_pred  = best_rf_model.predict(x_test)

# %%
print(f'Accuracy score of our model is : {metrics.accuracy_score(y_test,rf_y_pred)}')
print(f'Confusion matrix is : {metrics.confusion_matrix(y_test,rf_y_pred)}')
print(f'Accuracy score is :{metrics.classification_report(y_test,rf_y_pred)} ')
cvs2 = cross_val_score(RandomForestClassifier(),x,y,cv=5)
print(f'Cross val score:{cvs2.mean()}')
# Out:
# Accuracy score of our model is : 0.8367346938775511
# Confusion matrix is : [[239   2]
#  [ 46   7]]
# Accuracy score is :              precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       241
#            1       0.78      0.13      0.23        53
#
#     accuracy                           0.84       294
#    macro avg       0.81      0.56      0.57       294
# weighted avg       0.83      0.84      0.79       294
#
# Cross val score:0.8571428571428571

# %% [markdown]
# <span style = "color:orange"> Visualize confusion matrix </span>

# %%
sns.heatmap(metrics.confusion_matrix(y_test,rf_y_pred),annot=True,fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
paras_1 = {'C':[0.75,0.85,0.95,1],'degree':[3,4,5],'kernel':['linear','poly','rbf','sigmoid']}

# %%
gsv_svm = GridSearchCV(SVC(),paras_1,cv=5)

# %%
gsv_svm.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.75, 0.85, 0.95, 1], 'degree': [3, 4, 5],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
print(f'Best estimator is: {gsv_svm.best_estimator_}')
print(f'Best parameters are: {gsv_svm.best_params_}')
print(f'Best score is : {gsv_svm.best_score_}')
# Out:
# Best estimator is: SVC(C=0.85, kernel='linear')
# Best parameters are: {'C': 0.85, 'degree': 3, 'kernel': 'linear'}
# Best score is : 0.8800973674720518

# %%
best_svm_model = SVC(C=0.85, kernel='linear', degree = 3)

# %%
best_svm_model.fit(x_train,y_train)
# Out:
# SVC(C=0.85, kernel='linear')

# %%
svm_y_pred=best_svm_model.predict(x_test)

# %%
print(f'Accuracy score is: {metrics.accuracy_score(y_test,svm_y_pred)}')
print(f'Confusion metrics: {metrics.confusion_matrix(y_test,svm_y_pred)}')
print(f'Classification report: {metrics.classification_report(y_test,svm_y_pred)}')
cvs1 = cross_val_score(SVC(),x,y,cv=5)
print(f'Cross val score:{cvs1.mean()}')
# Out:
# Accuracy score is: 0.8741496598639455
# Confusion metrics: [[236   5]
#  [ 32  21]]
# Classification report:               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       241
#            1       0.81      0.40      0.53        53
#
#     accuracy                           0.87       294
#    macro avg       0.84      0.69      0.73       294
# weighted avg       0.87      0.87      0.86       294
#
# Cross val score:0.8673469387755102

# %% [markdown]
# <span style = "color:orange"> Visualize confusion matrix </span>

# %%
sns.heatmap(metrics.confusion_matrix(y_test,svm_y_pred),annot=True,fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### AdaBoost: Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
paras_2 = {'n_estimators':[50,100,200],'learning_rate':[0.01,0.1,1.0],'algorithm': ['SAMME', 'SAMME.R'],'random_state': [None, 42, 2022]}

# %%
gsv_ada = GridSearchCV(AdaBoostClassifier(),paras_2,cv=5)

# %%
gsv_ada.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.01, 0.1, 1.0],
#                          'n_estimators': [50, 100, 200],
#                          'random_state': [None, 42, 2022]})

# %%
print(f'Best estimator is: {gsv_ada.best_estimator_}')
print(f'Best parameters are: {gsv_ada.best_params_}')
print(f'Best score is : {gsv_ada.best_score_}')
# Out:
# Best estimator is: AdaBoostClassifier()
# Best parameters are: {'algorithm': 'SAMME.R', 'learning_rate': 1.0, 'n_estimators': 50, 'random_state': None}
# Best score is : 0.8783988460151461

# %%
best_ada_model = AdaBoostClassifier(algorithm= 'SAMME.R', learning_rate= 1.0, n_estimators= 50, random_state= None)

# %%
best_ada_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ada_y_pred = best_ada_model.predict(x_test)

# %%
print(f'Accuracy score is: {metrics.accuracy_score(y_test,svm_y_pred)}')
print(f'Confusion metrics: {metrics.confusion_matrix(y_test,svm_y_pred)}')
print(f'Classification report: {metrics.classification_report(y_test,svm_y_pred)}')
cvs = cross_val_score(AdaBoostClassifier(),x,y,cv=5)
print(f'Cross val score:{cvs.mean()}')
# Out:
# Accuracy score is: 0.8741496598639455
# Confusion metrics: [[236   5]
#  [ 32  21]]
# Classification report:               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       241
#            1       0.81      0.40      0.53        53
#
#     accuracy                           0.87       294
#    macro avg       0.84      0.69      0.73       294
# weighted avg       0.87      0.87      0.86       294
#
# Cross val score:0.8768707482993197

# %% [markdown]
# <span style = "color:orange"> Visualize confusion matrix </span>

# %%
sns.heatmap(metrics.confusion_matrix(y_test,svm_y_pred),annot=True,fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### View score of different models in one dataframe

# %%
models = {'LogisticRegression':model,'SVC':best_svm_model,'RandomForestClassifier':best_rf_model,'AdaBoostClassifier':best_ada_model}
model_name=[]
score_mean=[]
for key,value in models.items():
    score = cross_val_score(value,x,y,cv=5)
    model_name.append(key)
    score_mean.append(score.mean())
    print (score.mean())
# Out:
# 0.8829931972789116
# 0.882312925170068
# 0.8557823129251702
# 0.8768707482993197

# %%
score_df = pd.DataFrame({'Models':model_name,'Score':score_mean})
score_df.sort_values(by='Score',ascending=False)
# Out:
#                    Models     Score
# 0      LogisticRegression  0.882993
# 1                     SVC  0.882313
# 3      AdaBoostClassifier  0.876871
# 2  RandomForestClassifier  0.855782

# %% [markdown]
# ## Use PCA to reduce dimensionality of the data

# %% [markdown]
# #### Import PCA and fit our X_train

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=4)

# %%
pca.fit(x_train)
# Out:
# PCA(n_components=4)

# %% [markdown]
# #### Apply the mapping (transform) to both the training set and the test set.

# %%
train_X = pca.transform(x_train)
test_X = pca.transform(x_test)

# %% [markdown]
# #### Import machine learning model of our choice, we are going with RandomForest for this problem

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Create RandomForest model with the best parameter we got earlier and train it

# %%
best_rf_model
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=32, n_jobs=1, random_state=1)

# %% [markdown]
# #### Check the score of our model

# %%
best_rf_model.score(x_train,y_train)
# Out:
# 0.9770408163265306

# %% [markdown]
# #### Make predictions with X_test and check the accuracy score

# %%
rf_y_pred1 = best_rf_model.predict(x_test)

# %%
print(f'Accuracy Score is : {metrics.accuracy_score(y_test,rf_y_pred1)}')
# Out:
# Accuracy Score is : 0.8367346938775511

# %% [markdown]
# ### Print Confusion matrix and Classification report

# %%
print(f'Confusion matrix is : {metrics.confusion_matrix(y_test,rf_y_pred1)}')
# Out:
# Confusion matrix is : [[239   2]
#  [ 46   7]]

# %%
print(f'Classification report is : {metrics.classification_report(y_test,rf_y_pred1)}')
# Out:
# Classification report is :               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       241
#            1       0.78      0.13      0.23        53
#
#     accuracy                           0.84       294
#    macro avg       0.81      0.56      0.57       294
# weighted avg       0.83      0.84      0.79       294

# %% [markdown]
# # <span style = "color:green"> Good Job! You have Successfully completed one Capstone Project </span>

# %% [markdown]
# ***
